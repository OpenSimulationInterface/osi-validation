# %%
from osi_data_container import OsiDataContainer
odc = OsiDataContainer()
odc.from_file('/home/aina/Desktop/overtake_right_straight_SensorView.txt')

mo = odc.data[0].global_ground_truth.moving_object[0]
sv = odc.data[0]
# Out:
# Data file /home/aina/Desktop/overtake_right_straight_SensorView.txt contained 1479 timestamps.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from osi_rule_checker import OsiRuleChecker
from osi_validation_rules import OsiValidationRules
from collections import namedtuple

ovr = OsiValidationRules()
ovr.from_yaml_directory('requirements-osi-3')


#ovr.check_message([mo], ovr._rules['MovingObject'])
#display(ovr._rules)

fake_field_descriptor = namedtuple('fake_field_descriptor',['name']) 
fake_field_descriptor.name = "SensorView"
ovr.check_message([(fake_field_descriptor, sv)], ovr._rules['SensorView'])
# Out:
# ERROR:SensorView.version is not set!
# DEBUG:SensorView.timestamp is set as expected
# DEBUG:Minimum: 0
# DEBUG:is_minimum for SensorView.timestamp.seconds OK
# DEBUG:435000000 in range: (0.0, 999999999.0)
# DEBUG:in_range for SensorView.timestamp.nanos OK
# DEBUG:is_set for SensorView.timestamp OK
# DEBUG:Check reference many to many
# ERROR:Reference error
# WARNING:refers for SensorView.sensor_id Not OK
# DEBUG:Minimum: 0
# DEBUG:is_minimum for SensorView.sensor_id.value OK
# DEBUG:is_valid for SensorView.sensor_id OK
# ERROR:SensorView.mounting_position is not set!
# ERROR:SensorView.mounting_position_rmse is not set!
# ERROR:SensorView.host_vehicle_data is not set!
# DEBUG:SensorView.global_ground_truth is set as expected
# DEBUG:SensorView.global_ground_truth.version is set as expected
# DEBUG:SensorView.global_ground_truth.version.version_major is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.version.version_major OK
# DEBUG:SensorView.global_ground_truth.version.version_minor is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.version.version_minor OK
# DEBUG:SensorView.global_ground_truth.version.version_patch is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.version.version_patch OK
# DEBUG:is_set for SensorView.global_ground_truth.version OK
# DEBUG:SensorView.global_ground_truth.timestamp is set as expected
# DEBUG:Minimum: 0
# DEBUG:is_minimum for SensorView.global_ground_truth.timestamp.seconds OK
# DEBUG:435000000 in range: (0.0, 999999999.0)
# DEBUG:in_range for SensorView.global_ground_truth.timestamp.nanos OK
# DEBUG:is_set for SensorView.global_ground_truth.timestamp OK
# DEBUG:Check reference many to one
# DEBUG:refers for SensorView.global_ground_truth.host_vehicle_id OK
# DEBUG:Minimum: 0
# DEBUG:is_minimum for SensorView.global_ground_truth.host_vehicle_id.value OK
# DEBUG:is_valid for SensorView.global_ground_truth.host_vehicle_id OK
# DEBUG:SensorView.global_ground_truth.environmental_conditions is set as expected
# DEBUG:SensorView.global_ground_truth.environmental_conditions.ambient_illumination is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.environmental_conditions.ambient_illumination OK
# DEBUG:SensorView.global_ground_truth.environmental_conditions.time_of_day is set as expected
# DEBUG:Contained type!
# DEBUG:52200 in range: (0.0, 86400.0)
# DEBUG:in_range for SensorView.global_ground_truth.environmental_conditions.time_of_day.seconds_since_midnight OK
# DEBUG:is_set for SensorView.global_ground_truth.environmental_conditions.time_of_day OK
# DEBUG:SensorView.global_ground_truth.environmental_conditions.atmospheric_pressure is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.environmental_conditions.atmospheric_pressure OK
# ERROR:0.0 not in range: (80000.0, 120000.0)
# WARNING:in_range for SensorView.global_ground_truth.environmental_conditions.atmospheric_pressure Not OK
# DEBUG:SensorView.global_ground_truth.environmental_conditions.temperature is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.environmental_conditions.temperature OK
# ERROR:0.0 not in range: (170.0, 340.0)
# WARNING:in_range for SensorView.global_ground_truth.environmental_conditions.temperature Not OK
# DEBUG:SensorView.global_ground_truth.environmental_conditions.relative_humidity is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.environmental_conditions.relative_humidity OK
# DEBUG:0.0 in range: (0.0, 100.0)
# DEBUG:in_range for SensorView.global_ground_truth.environmental_conditions.relative_humidity OK
# DEBUG:SensorView.global_ground_truth.environmental_conditions.precipitation is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.environmental_conditions.precipitation OK
# DEBUG:SensorView.global_ground_truth.environmental_conditions.fog is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.environmental_conditions.fog OK
# WARNING:is_set for SensorView.global_ground_truth.environmental_conditions Not OK
# DEBUG:Checking ISO code for 0
# WARNING:is_iso_country_code for SensorView.global_ground_truth.country_code Not OK
# DEBUG:Check the rule is_valid for a repeated field
# DEBUG:SensorView.global_ground_truth.id is set as expected
# DEBUG:Minimum: 0
# DEBUG:is_minimum for SensorView.global_ground_truth.id.value OK
# DEBUG:is_set for SensorView.global_ground_truth.id OK
# DEBUG:is_global_unique for SensorView.global_ground_truth.id OK
# WARNING:The message type 'BaseMoving' has no rule
# DEBUG:is_valid for SensorView.global_ground_truth.base OK
# DEBUG:Check the rule is_valid for a repeated field
# DEBUG:Minimum: 0
# DEBUG:is_minimum for SensorView.global_ground_truth.value OK
# DEBUG:is_valid for SensorView.global_ground_truth.assigned_lane_id OK
# WARNING:The message type 'VehicleAttributes' has no rule
# DEBUG:is_valid for SensorView.global_ground_truth.vehicle_attributes OK
# WARNING:The message type 'VehicleClassification' has no rule
# DEBUG:is_valid for SensorView.global_ground_truth.vehicle_classification OK
# DEBUG:SensorView.global_ground_truth.id is set as expected
# DEBUG:Minimum: 0
# DEBUG:is_minimum for SensorView.global_ground_truth.id.value OK
# DEBUG:is_set for SensorView.global_ground_truth.id OK
# DEBUG:is_global_unique for SensorView.global_ground_truth.id OK
# WARNING:The message type 'BaseMoving' has no rule
# DEBUG:is_valid for SensorView.global_ground_truth.base OK
# DEBUG:Check the rule is_valid for a repeated field
# DEBUG:Minimum: 0
# DEBUG:is_minimum for SensorView.global_ground_truth.value OK
# DEBUG:is_valid for SensorView.global_ground_truth.assigned_lane_id OK
# WARNING:The message type 'VehicleAttributes' has no rule
# DEBUG:is_valid for SensorView.global_ground_truth.vehicle_attributes OK
# WARNING:The message type 'VehicleClassification' has no rule
# DEBUG:is_valid for SensorView.global_ground_truth.vehicle_classification OK
# DEBUG:is_valid for SensorView.global_ground_truth.moving_object OK
# DEBUG:Check the rule is_valid for a repeated field
# WARNING:The message type 'LaneBoundary' has no rule
# WARNING:The message type 'LaneBoundary' has no rule
# WARNING:The message type 'LaneBoundary' has no rule
# WARNING:The message type 'LaneBoundary' has no rule
# DEBUG:is_valid for SensorView.global_ground_truth.lane_boundary OK
# DEBUG:Check the rule is_valid for a repeated field
# DEBUG:is_global_unique for SensorView.global_ground_truth.id OK
# DEBUG:Minimum: 0
# DEBUG:is_minimum for SensorView.global_ground_truth.id.value OK
# DEBUG:is_valid for SensorView.global_ground_truth.id OK
# DEBUG:SensorView.global_ground_truth.classification is set as expected
# DEBUG:Contained type!
# DEBUG:SensorView.global_ground_truth.classification.type is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.type OK
# DEBUG:SensorView.global_ground_truth.classification.is_host_vehicle_lane is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.is_host_vehicle_lane OK
# DEBUG:SensorView.global_ground_truth.classification is set as expected: type != 4
# DEBUG:Check the rule is_set_if for a repeated field
# DEBUG:is_set_if for SensorView.global_ground_truth.classification.left_adjacent_lane_id OK
# DEBUG:Check the rule is_valid for a repeated field
# DEBUG:Minimum: 0
# DEBUG:is_minimum for SensorView.global_ground_truth.classification.value OK
# DEBUG:is_valid for SensorView.global_ground_truth.classification.left_adjacent_lane_id OK
# DEBUG:SensorView.global_ground_truth.classification is set as expected: type != 4
# ERROR:Field SensorView.global_ground_truth.classification.right_adjacent_lane_id does not exist
# DEBUG:['type', 'is_host_vehicle_lane', 'centerline', 'centerline_is_driving_direction', 'left_adjacent_lane_id', 'right_lane_boundary_id', 'left_lane_boundary_id', 'road_condition']
# DEBUG:SensorView.global_ground_truth.classification is set as expected: type != 4
# DEBUG:Check the rule is_set_if for a repeated field
# DEBUG:is_set_if for SensorView.global_ground_truth.classification.right_lane_boundary_id OK
# DEBUG:Check the rule is_valid for a repeated field
# DEBUG:Minimum: 0
# DEBUG:is_minimum for SensorView.global_ground_truth.classification.value OK
# DEBUG:is_valid for SensorView.global_ground_truth.classification.right_lane_boundary_id OK
# DEBUG:SensorView.global_ground_truth.classification is set as expected: type != 4
# DEBUG:Check the rule is_set_if for a repeated field
# DEBUG:is_set_if for SensorView.global_ground_truth.classification.left_lane_boundary_id OK
# DEBUG:Check the rule is_valid for a repeated field
# DEBUG:Minimum: 0
# DEBUG:is_minimum for SensorView.global_ground_truth.classification.value OK
# DEBUG:is_valid for SensorView.global_ground_truth.classification.left_lane_boundary_id OK
# DEBUG:SensorView.global_ground_truth.classification is set as expected: type != 4
# ERROR:Field SensorView.global_ground_truth.classification.free_lane_boundary_id does not exist
# DEBUG:['type', 'is_host_vehicle_lane', 'centerline', 'centerline_is_driving_direction', 'left_adjacent_lane_id', 'right_lane_boundary_id', 'left_lane_boundary_id', 'road_condition']
# DEBUG:SensorView.global_ground_truth.classification.road_condition is set as expected
# WARNING:The message type 'RoadCondition' has no rule
# DEBUG:is_set for SensorView.global_ground_truth.classification.road_condition OK
# DEBUG:Check the rule is_valid for a repeated field
# DEBUG:SensorView.global_ground_truth.classification.x is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.x OK
# DEBUG:SensorView.global_ground_truth.classification.y is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.y OK
# DEBUG:SensorView.global_ground_truth.classification.z is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.z OK
# DEBUG:SensorView.global_ground_truth.classification.x is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.x OK
# DEBUG:SensorView.global_ground_truth.classification.y is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.y OK
# DEBUG:SensorView.global_ground_truth.classification.z is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.z OK
# DEBUG:SensorView.global_ground_truth.classification.x is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.x OK
# DEBUG:SensorView.global_ground_truth.classification.y is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.y OK
# DEBUG:SensorView.global_ground_truth.classification.z is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.z OK
# DEBUG:SensorView.global_ground_truth.classification.x is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.x OK
# DEBUG:SensorView.global_ground_truth.classification.y is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.y OK
# DEBUG:SensorView.global_ground_truth.classification.z is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.z OK
# DEBUG:SensorView.global_ground_truth.classification.x is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.x OK
# DEBUG:SensorView.global_ground_truth.classification.y is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.y OK
# DEBUG:SensorView.global_ground_truth.classification.z is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.z OK
# DEBUG:SensorView.global_ground_truth.classification.x is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.x OK
# DEBUG:SensorView.global_ground_truth.classification.y is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.y OK
# DEBUG:SensorView.global_ground_truth.classification.z is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.z OK
# DEBUG:SensorView.global_ground_truth.classification.x is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.x OK
# DEBUG:SensorView.global_ground_truth.classification.y is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.y OK
# DEBUG:SensorView.global_ground_truth.classification.z is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.z OK
# DEBUG:SensorView.global_ground_truth.classification.x is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.x OK
# DEBUG:SensorView.global_ground_truth.classification.y is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.y OK
# DEBUG:SensorView.global_ground_truth.classification.z is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.z OK
# DEBUG:SensorView.global_ground_truth.classification.x is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.x OK
# DEBUG:SensorView.global_ground_truth.classification.y is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.y OK
# DEBUG:SensorView.global_ground_truth.classification.z is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.z OK
# DEBUG:SensorView.global_ground_truth.classification.x is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.x OK
# DEBUG:SensorView.global_ground_truth.classification.y is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.y OK
# DEBUG:SensorView.global_ground_truth.classification.z is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.z OK
# DEBUG:SensorView.global_ground_truth.classification.x is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.x OK
# DEBUG:SensorView.global_ground_truth.classification.y is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.y OK
# DEBUG:SensorView.global_ground_truth.classification.z is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.z OK
# DEBUG:SensorView.global_ground_truth.classification.x is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.x OK
# DEBUG:SensorView.global_ground_truth.classification.y is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.y OK
# DEBUG:SensorView.global_ground_truth.classification.z is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.z OK
# DEBUG:SensorView.global_ground_truth.classification.x is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.x OK
# DEBUG:SensorView.global_ground_truth.classification.y is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.y OK
# DEBUG:SensorView.global_ground_truth.classification.z is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.z OK
# DEBUG:SensorView.global_ground_truth.classification.x is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.x OK
# DEBUG:SensorView.global_ground_truth.classification.y is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.y OK
# DEBUG:SensorView.global_ground_truth.classification.z is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.z OK
# DEBUG:SensorView.global_ground_truth.classification.x is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.x OK
# DEBUG:SensorView.global_ground_truth.classification.y is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.y OK
# DEBUG:SensorView.global_ground_truth.classification.z is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.z OK
# DEBUG:SensorView.global_ground_truth.classification.x is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.x OK
# DEBUG:SensorView.global_ground_truth.classification.y is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.y OK
# DEBUG:SensorView.global_ground_truth.classification.z is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.z OK
# DEBUG:SensorView.global_ground_truth.classification.x is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.x OK
# DEBUG:SensorView.global_ground_truth.classification.y is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.y OK
# DEBUG:SensorView.global_ground_truth.classification.z is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.z OK
# DEBUG:SensorView.global_ground_truth.classification.x is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.x OK
# DEBUG:SensorView.global_ground_truth.classification.y is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.y OK
# DEBUG:SensorView.global_ground_truth.classification.z is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.z OK
# DEBUG:SensorView.global_ground_truth.classification.x is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.x OK
# DEBUG:SensorView.global_ground_truth.classification.y is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.y OK
# DEBUG:SensorView.global_ground_truth.classification.z is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.z OK
# DEBUG:SensorView.global_ground_truth.classification.x is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.x OK
# DEBUG:SensorView.global_ground_truth.classification.y is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.y OK
# DEBUG:SensorView.global_ground_truth.classification.z is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.z OK
# DEBUG:SensorView.global_ground_truth.classification.x is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.x OK
# DEBUG:SensorView.global_ground_truth.classification.y is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.y OK
# DEBUG:SensorView.global_ground_truth.classification.z is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.z OK
# DEBUG:SensorView.global_ground_truth.classification.x is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.x OK
# DEBUG:SensorView.global_ground_truth.classification.y is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.y OK
# DEBUG:SensorView.global_ground_truth.classification.z is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.z OK
# DEBUG:SensorView.global_ground_truth.classification.x is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.x OK
# DEBUG:SensorView.global_ground_truth.classification.y is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.y OK
# DEBUG:SensorView.global_ground_truth.classification.z is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.z OK
# DEBUG:SensorView.global_ground_truth.classification.x is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.x OK
# DEBUG:SensorView.global_ground_truth.classification.y is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.y OK
# DEBUG:SensorView.global_ground_truth.classification.z is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.z OK
# DEBUG:SensorView.global_ground_truth.classification.x is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.x OK
# DEBUG:SensorView.global_ground_truth.classification.y is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.y OK
# DEBUG:SensorView.global_ground_truth.classification.z is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.z OK
# DEBUG:SensorView.global_ground_truth.classification.x is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.x OK
# DEBUG:SensorView.global_ground_truth.classification.y is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.y OK
# DEBUG:SensorView.global_ground_truth.classification.z is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.z OK
# DEBUG:SensorView.global_ground_truth.classification.x is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.x OK
# DEBUG:SensorView.global_ground_truth.classification.y is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.y OK
# DEBUG:SensorView.global_ground_truth.classification.z is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.z OK
# DEBUG:SensorView.global_ground_truth.classification.x is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.x OK
# DEBUG:SensorView.global_ground_truth.classification.y is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.y OK
# DEBUG:SensorView.global_ground_truth.classification.z is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.z OK
# DEBUG:SensorView.global_ground_truth.classification.x is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.x OK
# DEBUG:SensorView.global_ground_truth.classification.y is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.y OK
# DEBUG:SensorView.global_ground_truth.classification.z is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.z OK
# DEBUG:SensorView.global_ground_truth.classification.x is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.x OK
# DEBUG:SensorView.global_ground_truth.classification.y is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.y OK
# DEBUG:SensorView.global_ground_truth.classification.z is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.z OK
# DEBUG:SensorView.global_ground_truth.classification.x is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.x OK
# DEBUG:SensorView.global_ground_truth.classification.y is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.y OK
# DEBUG:SensorView.global_ground_truth.classification.z is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.z OK
# DEBUG:SensorView.global_ground_truth.classification.x is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.x OK
# DEBUG:SensorView.global_ground_truth.classification.y is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.y OK
# DEBUG:SensorView.global_ground_truth.classification.z is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.z OK
# DEBUG:SensorView.global_ground_truth.classification.x is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.x OK
# DEBUG:SensorView.global_ground_truth.classification.y is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.y OK
# DEBUG:SensorView.global_ground_truth.classification.z is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.z OK
# DEBUG:SensorView.global_ground_truth.classification.x is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.x OK
# DEBUG:SensorView.global_ground_truth.classification.y is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.y OK
# DEBUG:SensorView.global_ground_truth.classification.z is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.z OK
# DEBUG:SensorView.global_ground_truth.classification.x is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.x OK
# DEBUG:SensorView.global_ground_truth.classification.y is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.y OK
# DEBUG:SensorView.global_ground_truth.classification.z is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.z OK
# DEBUG:SensorView.global_ground_truth.classification.x is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.x OK
# DEBUG:SensorView.global_ground_truth.classification.y is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.y OK
# DEBUG:SensorView.global_ground_truth.classification.z is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.z OK
# DEBUG:SensorView.global_ground_truth.classification.x is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.x OK
# DEBUG:SensorView.global_ground_truth.classification.y is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.y OK
# DEBUG:SensorView.global_ground_truth.classification.z is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.z OK
# DEBUG:SensorView.global_ground_truth.classification.x is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.x OK
# DEBUG:SensorView.global_ground_truth.classification.y is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.y OK
# DEBUG:SensorView.global_ground_truth.classification.z is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.z OK
# DEBUG:SensorView.global_ground_truth.classification.x is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.x OK
# DEBUG:SensorView.global_ground_truth.classification.y is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.y OK
# DEBUG:SensorView.global_ground_truth.classification.z is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.z OK
# DEBUG:SensorView.global_ground_truth.classification.x is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.x OK
# DEBUG:SensorView.global_ground_truth.classification.y is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.y OK
# DEBUG:SensorView.global_ground_truth.classification.z is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.z OK
# DEBUG:SensorView.global_ground_truth.classification.x is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.x OK
# DEBUG:SensorView.global_ground_truth.classification.y is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.y OK
# DEBUG:SensorView.global_ground_truth.classification.z is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.z OK
# DEBUG:SensorView.global_ground_truth.classification.x is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.x OK
# DEBUG:SensorView.global_ground_truth.classification.y is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.y OK
# DEBUG:SensorView.global_ground_truth.classification.z is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.z OK
# DEBUG:SensorView.global_ground_truth.classification.x is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.x OK
# DEBUG:SensorView.global_ground_truth.classification.y is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.y OK
# DEBUG:SensorView.global_ground_truth.classification.z is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.z OK
# DEBUG:SensorView.global_ground_truth.classification.x is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.x OK
# DEBUG:SensorView.global_ground_truth.classification.y is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.y OK
# DEBUG:SensorView.global_ground_truth.classification.z is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.z OK
# DEBUG:SensorView.global_ground_truth.classification.x is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.x OK
# DEBUG:SensorView.global_ground_truth.classification.y is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.y OK
# DEBUG:SensorView.global_ground_truth.classification.z is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.z OK
# DEBUG:SensorView.global_ground_truth.classification.x is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.x OK
# DEBUG:SensorView.global_ground_truth.classification.y is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.y OK
# DEBUG:SensorView.global_ground_truth.classification.z is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.z OK
# DEBUG:SensorView.global_ground_truth.classification.x is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.x OK
# DEBUG:SensorView.global_ground_truth.classification.y is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.y OK
# DEBUG:SensorView.global_ground_truth.classification.z is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.z OK
# DEBUG:SensorView.global_ground_truth.classification.x is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.x OK
# DEBUG:SensorView.global_ground_truth.classification.y is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.y OK
# DEBUG:SensorView.global_ground_truth.classification.z is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.z OK
# DEBUG:SensorView.global_ground_truth.classification.x is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.x OK
# DEBUG:SensorView.global_ground_truth.classification.y is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.y OK
# DEBUG:SensorView.global_ground_truth.classification.z is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.z OK
# DEBUG:SensorView.global_ground_truth.classification.x is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.x OK
# DEBUG:SensorView.global_ground_truth.classification.y is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.y OK
# DEBUG:SensorView.global_ground_truth.classification.z is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.z OK
# DEBUG:SensorView.global_ground_truth.classification.x is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.x OK
# DEBUG:SensorView.global_ground_truth.classification.y is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.y OK
# DEBUG:SensorView.global_ground_truth.classification.z is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.z OK
# DEBUG:SensorView.global_ground_truth.classification.x is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.x OK
# DEBUG:SensorView.global_ground_truth.classification.y is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.y OK
# DEBUG:SensorView.global_ground_truth.classification.z is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.z OK
# DEBUG:SensorView.global_ground_truth.classification.x is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.x OK
# DEBUG:SensorView.global_ground_truth.classification.y is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.y OK
# DEBUG:SensorView.global_ground_truth.classification.z is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.z OK
# DEBUG:SensorView.global_ground_truth.classification.x is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.x OK
# DEBUG:SensorView.global_ground_truth.classification.y is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.y OK
# DEBUG:SensorView.global_ground_truth.classification.z is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.z OK
# DEBUG:SensorView.global_ground_truth.classification.x is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.x OK
# DEBUG:SensorView.global_ground_truth.classification.y is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.y OK
# DEBUG:SensorView.global_ground_truth.classification.z is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.z OK
# DEBUG:SensorView.global_ground_truth.classification.x is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.x OK
# DEBUG:SensorView.global_ground_truth.classification.y is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.y OK
# DEBUG:SensorView.global_ground_truth.classification.z is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.z OK
# DEBUG:SensorView.global_ground_truth.classification.x is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.x OK
# DEBUG:SensorView.global_ground_truth.classification.y is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.y OK
# DEBUG:SensorView.global_ground_truth.classification.z is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.z OK
# DEBUG:SensorView.global_ground_truth.classification.x is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.x OK
# DEBUG:SensorView.global_ground_truth.classification.y is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.y OK
# DEBUG:SensorView.global_ground_truth.classification.z is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.z OK
# DEBUG:SensorView.global_ground_truth.classification.x is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.x OK
# DEBUG:SensorView.global_ground_truth.classification.y is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.y OK
# DEBUG:SensorView.global_ground_truth.classification.z is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.z OK
# DEBUG:SensorView.global_ground_truth.classification.x is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.x OK
# DEBUG:SensorView.global_ground_truth.classification.y is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.y OK
# DEBUG:SensorView.global_ground_truth.classification.z is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.z OK
# DEBUG:SensorView.global_ground_truth.classification.x is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.x OK
# DEBUG:SensorView.global_ground_truth.classification.y is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.y OK
# DEBUG:SensorView.global_ground_truth.classification.z is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.z OK
# DEBUG:SensorView.global_ground_truth.classification.x is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.x OK
# DEBUG:SensorView.global_ground_truth.classification.y is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.y OK
# DEBUG:SensorView.global_ground_truth.classification.z is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.z OK
# DEBUG:SensorView.global_ground_truth.classification.x is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.x OK
# DEBUG:SensorView.global_ground_truth.classification.y is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.y OK
# DEBUG:SensorView.global_ground_truth.classification.z is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.z OK
# DEBUG:SensorView.global_ground_truth.classification.x is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.x OK
# DEBUG:SensorView.global_ground_truth.classification.y is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.y OK
# DEBUG:SensorView.global_ground_truth.classification.z is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.z OK
# DEBUG:SensorView.global_ground_truth.classification.x is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.x OK
# DEBUG:SensorView.global_ground_truth.classification.y is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.y OK
# DEBUG:SensorView.global_ground_truth.classification.z is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.z OK
# DEBUG:SensorView.global_ground_truth.classification.x is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.x OK
# DEBUG:SensorView.global_ground_truth.classification.y is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.y OK
# DEBUG:SensorView.global_ground_truth.classification.z is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.z OK
# DEBUG:SensorView.global_ground_truth.classification.x is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.x OK
# DEBUG:SensorView.global_ground_truth.classification.y is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.y OK
# DEBUG:SensorView.global_ground_truth.classification.z is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.z OK
# DEBUG:SensorView.global_ground_truth.classification.x is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.x OK
# DEBUG:SensorView.global_ground_truth.classification.y is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.y OK
# DEBUG:SensorView.global_ground_truth.classification.z is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.z OK
# DEBUG:SensorView.global_ground_truth.classification.x is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.x OK
# DEBUG:SensorView.global_ground_truth.classification.y is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.y OK
# DEBUG:SensorView.global_ground_truth.classification.z is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.z OK
# DEBUG:SensorView.global_ground_truth.classification.x is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.x OK
# DEBUG:SensorView.global_ground_truth.classification.y is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.y OK
# DEBUG:SensorView.global_ground_truth.classification.z is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.z OK
# DEBUG:SensorView.global_ground_truth.classification.x is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.x OK
# DEBUG:SensorView.global_ground_truth.classification.y is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.y OK
# DEBUG:SensorView.global_ground_truth.classification.z is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.z OK
# DEBUG:SensorView.global_ground_truth.classification.x is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.x OK
# DEBUG:SensorView.global_ground_truth.classification.y is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.y OK
# DEBUG:SensorView.global_ground_truth.classification.z is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.z OK
# DEBUG:SensorView.global_ground_truth.classification.x is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.x OK
# DEBUG:SensorView.global_ground_truth.classification.y is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.y OK
# DEBUG:SensorView.global_ground_truth.classification.z is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.z OK
# DEBUG:SensorView.global_ground_truth.classification.x is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.x OK
# DEBUG:SensorView.global_ground_truth.classification.y is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.y OK
# DEBUG:SensorView.global_ground_truth.classification.z is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.z OK
# DEBUG:SensorView.global_ground_truth.classification.x is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.x OK
# DEBUG:SensorView.global_ground_truth.classification.y is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.y OK
# DEBUG:SensorView.global_ground_truth.classification.z is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.z OK
# DEBUG:SensorView.global_ground_truth.classification.x is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.x OK
# DEBUG:SensorView.global_ground_truth.classification.y is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.y OK
# DEBUG:SensorView.global_ground_truth.classification.z is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.z OK
# DEBUG:SensorView.global_ground_truth.classification.x is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.x OK
# DEBUG:SensorView.global_ground_truth.classification.y is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.y OK
# DEBUG:SensorView.global_ground_truth.classification.z is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.z OK
# DEBUG:SensorView.global_ground_truth.classification.x is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.x OK
# DEBUG:SensorView.global_ground_truth.classification.y is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.y OK
# DEBUG:SensorView.global_ground_truth.classification.z is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.z OK
# DEBUG:SensorView.global_ground_truth.classification.x is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.x OK
# DEBUG:SensorView.global_ground_truth.classification.y is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.y OK
# DEBUG:SensorView.global_ground_truth.classification.z is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.z OK
# DEBUG:SensorView.global_ground_truth.classification.x is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.x OK
# DEBUG:SensorView.global_ground_truth.classification.y is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.y OK
# DEBUG:SensorView.global_ground_truth.classification.z is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.z OK
# DEBUG:SensorView.global_ground_truth.classification.x is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.x OK
# DEBUG:SensorView.global_ground_truth.classification.y is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.y OK
# DEBUG:SensorView.global_ground_truth.classification.z is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.z OK
# DEBUG:SensorView.global_ground_truth.classification.x is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.x OK
# DEBUG:SensorView.global_ground_truth.classification.y is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.y OK
# DEBUG:SensorView.global_ground_truth.classification.z is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.z OK
# DEBUG:SensorView.global_ground_truth.classification.x is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.x OK
# DEBUG:SensorView.global_ground_truth.classification.y is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.y OK
# DEBUG:SensorView.global_ground_truth.classification.z is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.z OK
# DEBUG:SensorView.global_ground_truth.classification.x is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.x OK
# DEBUG:SensorView.global_ground_truth.classification.y is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.y OK
# DEBUG:SensorView.global_ground_truth.classification.z is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.z OK
# DEBUG:SensorView.global_ground_truth.classification.x is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.x OK
# DEBUG:SensorView.global_ground_truth.classification.y is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.y OK
# DEBUG:SensorView.global_ground_truth.classification.z is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.z OK
# DEBUG:SensorView.global_ground_truth.classification.x is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.x OK
# DEBUG:SensorView.global_ground_truth.classification.y is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.y OK
# DEBUG:SensorView.global_ground_truth.classification.z is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.z OK
# DEBUG:SensorView.global_ground_truth.classification.x is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.x OK
# DEBUG:SensorView.global_ground_truth.classification.y is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.y OK
# DEBUG:SensorView.global_ground_truth.classification.z is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.z OK
# DEBUG:SensorView.global_ground_truth.classification.x is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.x OK
# DEBUG:SensorView.global_ground_truth.classification.y is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.y OK
# DEBUG:SensorView.global_ground_truth.classification.z is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.z OK
# DEBUG:SensorView.global_ground_truth.classification.x is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.x OK
# DEBUG:SensorView.global_ground_truth.classification.y is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.y OK
# DEBUG:SensorView.global_ground_truth.classification.z is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.z OK
# DEBUG:SensorView.global_ground_truth.classification.x is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.x OK
# DEBUG:SensorView.global_ground_truth.classification.y is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.y OK
# DEBUG:SensorView.global_ground_truth.classification.z is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.z OK
# DEBUG:SensorView.global_ground_truth.classification.x is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.x OK
# DEBUG:SensorView.global_ground_truth.classification.y is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.y OK
# DEBUG:SensorView.global_ground_truth.classification.z is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.z OK
# DEBUG:SensorView.global_ground_truth.classification.x is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.x OK
# DEBUG:SensorView.global_ground_truth.classification.y is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.y OK
# ...
# DEBUG:SensorView.global_ground_truth.classification.x is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.x OK
# DEBUG:SensorView.global_ground_truth.classification.y is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.y OK
# DEBUG:SensorView.global_ground_truth.classification.z is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.z OK
# DEBUG:SensorView.global_ground_truth.classification.x is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.x OK
# DEBUG:SensorView.global_ground_truth.classification.y is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.y OK
# DEBUG:SensorView.global_ground_truth.classification.z is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.z OK
# DEBUG:SensorView.global_ground_truth.classification.x is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.x OK
# DEBUG:SensorView.global_ground_truth.classification.y is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.y OK
# DEBUG:SensorView.global_ground_truth.classification.z is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.z OK
# DEBUG:SensorView.global_ground_truth.classification.x is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.x OK
# DEBUG:SensorView.global_ground_truth.classification.y is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.y OK
# DEBUG:SensorView.global_ground_truth.classification.z is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.z OK
# DEBUG:SensorView.global_ground_truth.classification.x is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.x OK
# DEBUG:SensorView.global_ground_truth.classification.y is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.y OK
# DEBUG:SensorView.global_ground_truth.classification.z is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.z OK
# DEBUG:SensorView.global_ground_truth.classification.x is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.x OK
# DEBUG:SensorView.global_ground_truth.classification.y is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.y OK
# DEBUG:SensorView.global_ground_truth.classification.z is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.z OK
# DEBUG:SensorView.global_ground_truth.classification.x is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.x OK
# DEBUG:SensorView.global_ground_truth.classification.y is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.y OK
# DEBUG:SensorView.global_ground_truth.classification.z is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.z OK
# DEBUG:SensorView.global_ground_truth.classification.x is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.x OK
# DEBUG:SensorView.global_ground_truth.classification.y is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.y OK
# DEBUG:SensorView.global_ground_truth.classification.z is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.z OK
# DEBUG:SensorView.global_ground_truth.classification.x is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.x OK
# DEBUG:SensorView.global_ground_truth.classification.y is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.y OK
# DEBUG:SensorView.global_ground_truth.classification.z is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.z OK
# DEBUG:SensorView.global_ground_truth.classification.x is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.x OK
# DEBUG:SensorView.global_ground_truth.classification.y is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.y OK
# DEBUG:SensorView.global_ground_truth.classification.z is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.z OK
# DEBUG:SensorView.global_ground_truth.classification.x is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.x OK
# DEBUG:SensorView.global_ground_truth.classification.y is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.y OK
# DEBUG:SensorView.global_ground_truth.classification.z is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.z OK
# DEBUG:SensorView.global_ground_truth.classification.x is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.x OK
# DEBUG:SensorView.global_ground_truth.classification.y is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.y OK
# DEBUG:SensorView.global_ground_truth.classification.z is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.z OK
# DEBUG:SensorView.global_ground_truth.classification.x is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.x OK
# DEBUG:SensorView.global_ground_truth.classification.y is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.y OK
# DEBUG:SensorView.global_ground_truth.classification.z is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.z OK
# DEBUG:SensorView.global_ground_truth.classification.x is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.x OK
# DEBUG:SensorView.global_ground_truth.classification.y is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.y OK
# DEBUG:SensorView.global_ground_truth.classification.z is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.z OK
# DEBUG:SensorView.global_ground_truth.classification.x is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.x OK
# DEBUG:SensorView.global_ground_truth.classification.y is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.y OK
# DEBUG:SensorView.global_ground_truth.classification.z is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.z OK
# DEBUG:SensorView.global_ground_truth.classification.x is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.x OK
# DEBUG:SensorView.global_ground_truth.classification.y is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.y OK
# DEBUG:SensorView.global_ground_truth.classification.z is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.z OK
# DEBUG:SensorView.global_ground_truth.classification.x is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.x OK
# DEBUG:SensorView.global_ground_truth.classification.y is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.y OK
# DEBUG:SensorView.global_ground_truth.classification.z is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.z OK
# DEBUG:SensorView.global_ground_truth.classification.x is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.x OK
# DEBUG:SensorView.global_ground_truth.classification.y is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.y OK
# DEBUG:SensorView.global_ground_truth.classification.z is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.z OK
# DEBUG:SensorView.global_ground_truth.classification.x is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.x OK
# DEBUG:SensorView.global_ground_truth.classification.y is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.y OK
# DEBUG:SensorView.global_ground_truth.classification.z is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.z OK
# DEBUG:SensorView.global_ground_truth.classification.x is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.x OK
# DEBUG:SensorView.global_ground_truth.classification.y is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.y OK
# DEBUG:SensorView.global_ground_truth.classification.z is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.z OK
# DEBUG:SensorView.global_ground_truth.classification.x is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.x OK
# DEBUG:SensorView.global_ground_truth.classification.y is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.y OK
# DEBUG:SensorView.global_ground_truth.classification.z is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.z OK
# DEBUG:SensorView.global_ground_truth.classification.x is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.x OK
# DEBUG:SensorView.global_ground_truth.classification.y is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.y OK
# DEBUG:SensorView.global_ground_truth.classification.z is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.z OK
# DEBUG:SensorView.global_ground_truth.classification.x is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.x OK
# DEBUG:SensorView.global_ground_truth.classification.y is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.y OK
# DEBUG:SensorView.global_ground_truth.classification.z is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.z OK
# DEBUG:SensorView.global_ground_truth.classification.x is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.x OK
# DEBUG:SensorView.global_ground_truth.classification.y is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.y OK
# DEBUG:SensorView.global_ground_truth.classification.z is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.z OK
# DEBUG:SensorView.global_ground_truth.classification.x is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.x OK
# DEBUG:SensorView.global_ground_truth.classification.y is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.y OK
# DEBUG:SensorView.global_ground_truth.classification.z is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.z OK
# DEBUG:SensorView.global_ground_truth.classification.x is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.x OK
# DEBUG:SensorView.global_ground_truth.classification.y is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.y OK
# DEBUG:SensorView.global_ground_truth.classification.z is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.z OK
# DEBUG:SensorView.global_ground_truth.classification.x is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.x OK
# DEBUG:SensorView.global_ground_truth.classification.y is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.y OK
# DEBUG:SensorView.global_ground_truth.classification.z is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.z OK
# DEBUG:SensorView.global_ground_truth.classification.x is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.x OK
# DEBUG:SensorView.global_ground_truth.classification.y is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.y OK
# DEBUG:SensorView.global_ground_truth.classification.z is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.z OK
# DEBUG:SensorView.global_ground_truth.classification.x is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.x OK
# DEBUG:SensorView.global_ground_truth.classification.y is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.y OK
# DEBUG:SensorView.global_ground_truth.classification.z is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.z OK
# DEBUG:SensorView.global_ground_truth.classification.x is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.x OK
# DEBUG:SensorView.global_ground_truth.classification.y is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.y OK
# DEBUG:SensorView.global_ground_truth.classification.z is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.z OK
# DEBUG:SensorView.global_ground_truth.classification.x is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.x OK
# DEBUG:SensorView.global_ground_truth.classification.y is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.y OK
# DEBUG:SensorView.global_ground_truth.classification.z is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.z OK
# DEBUG:SensorView.global_ground_truth.classification.x is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.x OK
# DEBUG:SensorView.global_ground_truth.classification.y is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.y OK
# DEBUG:SensorView.global_ground_truth.classification.z is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.z OK
# DEBUG:SensorView.global_ground_truth.classification.x is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.x OK
# DEBUG:SensorView.global_ground_truth.classification.y is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.y OK
# DEBUG:SensorView.global_ground_truth.classification.z is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.z OK
# DEBUG:SensorView.global_ground_truth.classification.x is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.x OK
# DEBUG:SensorView.global_ground_truth.classification.y is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.y OK
# DEBUG:SensorView.global_ground_truth.classification.z is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.z OK
# DEBUG:SensorView.global_ground_truth.classification.x is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.x OK
# DEBUG:SensorView.global_ground_truth.classification.y is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.y OK
# DEBUG:SensorView.global_ground_truth.classification.z is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.z OK
# DEBUG:SensorView.global_ground_truth.classification.x is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.x OK
# DEBUG:SensorView.global_ground_truth.classification.y is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.y OK
# DEBUG:SensorView.global_ground_truth.classification.z is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.z OK
# DEBUG:SensorView.global_ground_truth.classification.x is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.x OK
# DEBUG:SensorView.global_ground_truth.classification.y is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.y OK
# DEBUG:SensorView.global_ground_truth.classification.z is set as expected
# DEBUG:is_set for SensorView.global_ground_truth.classification.z OK
# DEBUG:is_valid for SensorView.global_ground_truth.classification.centerline OK
# DEBUG:is_set for SensorView.global_ground_truth.classification OK
# DEBUG:is_valid for SensorView.global_ground_truth.lane OK
# WARNING:is_set for SensorView.global_ground_truth Not OK
# ERROR:SensorView.host_vehicle_id is not set!
# False

# %%
# saved ID
list(map(type, ovr._identifiers[0]))
# Out:
# [tuple]

# %%
for desc, value in sv.ListFields():
    print(desc.name)
    
list_field_mo = sv.ListFields()

fields = list_field_mo[2][1].ListFields()

fields[2]
# Out:
# timestamp
# sensor_id
# global_ground_truth
# (<google.protobuf.pyext._message.FieldDescriptor at 0x7f6be007a210>, value: 0)

# %%
ovr._rules
# Out:
# {'InterfaceVersion': {'version_major': ['is_set'],
#   'version_minor': ['is_set'],
#   'version_patch': ['is_set']},
#  'SensorView': {'version': ['is_set'],
#   'timestamp': ['is_set'],
#   'sensor_id': [{'refers': '+virtual_sensors'}, 'is_valid'],
#   'mounting_position': ['is_set'],
#   'mounting_position_rmse': ['is_set'],
#   'host_vehicle_data': ['is_set'],
#   'global_ground_truth': ['is_set'],
#   'host_vehicle_id': ['is_set', {'refers': '$host_vehicle_id'}]},
#  'GroundTruth': {'version': ['is_set'],
#   'timestamp': ['is_set'],
#   'host_vehicle_id': [{'refers': '$host_vehicle_id'}, 'is_valid'],
#   'environmental_conditions': ['is_set'],
#   'country_code': ['is_iso_country_code'],
#   'moving_object': ['is_valid'],
#   'lane_boundary': ['is_valid'],
#   'lane': ['is_valid']},
#  'EnvironmentalConditions': {'ambient_illumination': ['is_set'],
#   'time_of_day': ['is_set'],
#   'atmospheric_pressure': ['is_set', {'in_range': ['800e+2', '1200e+2']}],
#   'temperature': ['is_set', {'in_range': [170, 340]}],
#   'relative_humidity': ['is_set', {'in_range': [0, 100]}],
#   'precipitation': ['is_set'],
#   'fog': ['is_set'],
#   'TimeOfDay': {'seconds_since_midnight': [{'in_range': [0, 86400, 'ro']}]}},
#  'Identifier': {'value': [{'is_minimum': 0}]},
#  'Timestamp': {'seconds': [{'is_minimum': 0}],
#   'nanos': [{'in_range': [0, 999999999]}]},
#  'MovingObject': {'id': ['is_set', 'is_global_unique'],
#   'base': ['is_valid'],
#   'assigned_lane_id': ['is_valid'],
#   'vehicle_attributes': ['is_valid'],
#   'vehicle_classification': ['is_valid']}}

# %%
x = 2
a = eval("x+1==1", {'x': 0})

a
# Out:
# True
